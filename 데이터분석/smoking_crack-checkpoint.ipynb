# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
import pandas as pd
import numpy as np
import os
# %matplotlib inline

try : 
    if platform.system() == 'Windows':
    # 윈도우인 경우
        font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
        rc('font', family=font_name)
    else:    
    # Mac 인 경우
        rc('font', family='AppleGothic')
except : 
    pass
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
base_path = r'C:\Users\grand\Desktop\smoking\smoking_crack'
base_path1 = r'C:\Users\grand\Desktop\smoking'

# %%
#관악구
df_kwanak_crack = pd.read_excel(os.path.join(base_path, 'kwanak_crack.xlsx'))
df_kwanak_crack['지역구'] ='관악구'
df_kwanak_crack.set_index('지역구', inplace=True)
df_kwanak_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 관악구  2012     255     141
# 관악구  2013     411      64
# 관악구  2014    2122    1252
# 관악구  2015    1731     964
# 관악구  2016    1715    1202
# 관악구  2017     582     374
# 관악구  2018     781     535
# 관악구  2019     702     573
# 관악구  2020     868     305

# %%
# 연도 회전, y값 회수, 제목 구 이름
a1 = df_kwanak_crack.plot(kind='bar', x='연도')

# %%
#광진구

df_kwangjjin_crack = pd.read_csv(os.path.join(base_path, 'kwangjin_crack.csv'))
df_kwangjjin_crack['지역구'] = '광진구'
df_kwangjjin_crack.set_index('지역구', inplace=True)
df_kwangjjin_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 광진구  2016     410     589
# 광진구  2017     420    1151
# 광진구  2018     485    1415
# 광진구  2019     396    1115
# 광진구  2020     519    1037

# %%
#구로구
df_guro_crack = pd.read_csv(os.path.join(base_path, 'guro_crack.csv'))
dansok = []
minwon = []
year =[]
n_year = []
a=0
for i in df_guro_crack['흡연단속건수']:
    if a % 2 == 0:
        dansok += [i]
    else:
        minwon += [i]
    a+=1
for i in df_guro_crack['연도']:
    year += [i]
    
for v in year:
    if v not in n_year:
        n_year.append(v)
data = {'연도': n_year, '흡연민원건수': minwon, '흡연단속건수': dansok}
df_guro_crack = pd.DataFrame(data)
df_guro_crack['지역구'] = '구로구'
df_guro_crack.set_index('지역구', inplace=True)
df_guro_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 구로구  2016     782    1564
# 구로구  2017     672    1344
# 구로구  2018     696    1392
# 구로구  2019     537    1074
# 구로구  2020     765    1530

# %%
#강남구
df_gangnam_crack = pd.read_csv(os.path.join(base_path, 'gangnam_crack.csv'))
df_gangnam_crack['지역구'] = '강남구'
df_gangnam_crack.set_index('지역구', inplace=True)
df_gangnam_crack.rename(columns={'년도' : '연도'}, inplace=True)
df_gangnam_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 강남구  2017    2003    1667
# 강남구  2018    2220    1224
# 강남구  2019    2264    1516
# 강남구  2020    2261     903
# 강남구  2021    1380     542

# %%
# 서초구
df_seocho_crack = pd.read_csv(os.path.join(base_path, 'seocho_crack.csv'))
df_seocho_crack.drop(['흡연부스 설치 현황'], axis=1, inplace=True)
df_seocho_crack.rename(columns={'년도' : 'year', '단속건수' :'흡연단속건수'}, inplace=True)
df_seocho_crack['nyear'] = df_seocho_crack.year.transform(lambda year: str(year)[:4])
df_seocho_crack.drop(['year'], axis=1, inplace=True)
df_seocho_crack  = df_seocho_crack[['nyear', '흡연민원건수', '흡연단속건수']]
a = df_seocho_crack[3:6]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_e = pd.DataFrame(data)
df_e
df_seocho_crack.rename(columns={'nyear' : '연도'}, inplace=True)
df_seocho_crack = df_seocho_crack[0:3]
df_seocho_crack = pd.concat([df_seocho_crack, df_e], ignore_index=True)
df_seocho_crack['지역구'] = '서초구'
df_seocho_crack.set_index('지역구', inplace=True)
df_seocho_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 서초구  2017     720   26391
# 서초구  2018     955   18728
# 서초구  2019    1120   19424
# 서초구  2020    1330    5469

# %%
# 송파구
df_songpa_crack = pd.read_csv(os.path.join(base_path, 'songpa_crack.csv'))
df_songpa_crack.drop(['흡연부스'], axis=1, inplace=True)
df_songpa_crack.rename(columns={'연도별' : '연도', '흡연민원' : '흡연민원건수', '흡연단속' : '흡연단속건수'}, inplace=True)
df_songpa_crack["흡연민원건수"] = df_songpa_crack["흡연민원건수"].str.replace(pat=r'[^\w]', repl=r'', regex=True)
df_songpa_crack["흡연단속건수"] = df_songpa_crack["흡연단속건수"].str.replace(pat=r'[^\w]', repl=r'', regex=True)
df_songpa_crack = df_songpa_crack.astype(int)
df_songpa_crack
df_songpa_crack['지역구'] = '송파구'
df_songpa_crack.set_index('지역구', inplace=True)
df_songpa_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 송파구  2012      59       0
# 송파구  2013     289     910
# 송파구  2014     776    1918
# 송파구  2015     935    2773
# 송파구  2016    1091    2561
# 송파구  2017    1697    2487
# 송파구  2018    1852    2332
# 송파구  2019    2241    3572
# 송파구  2020    3508    2529
# 송파구  2021    2090    3236

# %%
df_songpa_crack["흡연민원건수"] = df_songpa_crack["흡연민원건수"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

# %%
# 양천구
df_yangcheon_crack = pd.read_csv(os.path.join(base_path, 'yangcheon_crack.csv'))
df_yangcheon_crack.drop(['점검건수', '실내 금연구역 개수', '실외 금연구역 개수'],axis=1, inplace=True)
df_yangcheon_crack.rename(columns={'단속건수' :'흡연단속건수'}, inplace=True)
df_yangcheon_crack['지역구'] = '양천구'
df_yangcheon_crack.set_index('지역구', inplace=True)
df_yangcheon_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 양천구  2015     241    1283
# 양천구  2016     293    1336
# 양천구  2017     303     979
# 양천구  2018     326     744
# 양천구  2019     291     988
# 양천구  2020     275     568
# 양천구  2021     253     492

# %%
# 동작1번째파일 (2014~2018)
df_dongjak_crack1 = pd.read_csv(os.path.join(base_path, 'dongjak1_crack.csv'))
dansok = []
minwon = []
year =[]
n_year = []
a=0
for i in df_dongjak_crack1['계']:
    if a % 2 == 0:
        minwon += [i]
    else:
        dansok += [i]
    a+=1
for i in df_dongjak_crack1['연도']:
    year += [i]
    
for v in year:
    if v not in n_year:
        n_year.append(v)
data = {'연도': n_year, '흡연민원건수': minwon, '흡연단속건수': dansok}
df_dongjak_crack1 = pd.DataFrame(data)
df_dongjak_crack1['지역구'] = '동작구'
df_dongjak_crack1.set_index('지역구', inplace=True)
# 동작2번째파일 (2019~2021)
df_dongjak_crack2 = pd.read_csv(os.path.join(base_path, 'dongjak2_crack.csv'))
df_dongjak_crack2.rename(columns={'구  분' : 'year', '단속건수' :'흡연단속건수'}, inplace=True)
df_dongjak_crack2['nyear'] = df_dongjak_crack2.year.transform(lambda year: str(year)[:4])
df_dongjak_crack2.drop(['year'], axis=1, inplace=True)
df_dongjak_crack2  = df_dongjak_crack2[['nyear', '흡연민원건수', '흡연단속건수']]
df_dongjak_crack2

a = df_dongjak_crack2[0:4]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2019 = pd.DataFrame(data)
a = df_dongjak_crack2[5:17]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2020 = pd.DataFrame(data)
a = df_dongjak_crack2[18:]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2021 = pd.DataFrame(data)
df_dongjak_crack2 = pd.concat([df_2019, df_2020, df_2021], ignore_index=True)
df_dongjak_crack = pd.concat([df_dongjak_crack1, df_dongjak_crack2], ignore_index=True)
df_dongjak_crack['지역구'] = '동작구'
df_dongjak_crack.set_index('지역구', inplace=True)
df_dongjak_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 동작구  2014     354     956
# 동작구  2015     491     524
# 동작구  2016     727     485
# 동작구  2017     604     525
# 동작구  2018     672     520
# 동작구  2019     164     271
# 동작구  2020     311     559
# 동작구  2021     400     169

# %%
# 은평구
df_eunpyeong_crack = pd.read_csv(os.path.join(base_path, 'eunpyeong_crack.csv'))
df_eunpyeong_crack.drop(['관리기관명','데이터기준일자'],axis=1, inplace=True)
df_eunpyeong_crack.rename(columns={'연월' : 'year', '민원처리건수' :'흡연민원건수', '과태료부과건수' : '흡연단속건수'}, inplace=True)
df_eunpyeong_crack['nyear'] = df_eunpyeong_crack.year.transform(lambda year: str(year)[:4])
df_eunpyeong_crack.drop(['year'], axis=1, inplace=True)
df_eunpyeong_crack  = df_eunpyeong_crack[['nyear', '흡연민원건수', '흡연단속건수']]
a = df_eunpyeong_crack[0:11]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2018 = pd.DataFrame(data)
a = df_eunpyeong_crack[12:23]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2019 = pd.DataFrame(data)
a = df_eunpyeong_crack[24:35]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2020 = pd.DataFrame(data)
a = df_eunpyeong_crack[36:]
a = a.sum()
b = a['nyear'][:4]
c = a['흡연민원건수']
d = a['흡연단속건수']
data = {'연도': [b], '흡연민원건수': [c], '흡연단속건수': [d]}
df_2021 = pd.DataFrame(data)
df_eunpyeong_crack = pd.concat([df_2018, df_2019, df_2020, df_2021], ignore_index=True)
df_eunpyeong_crack['지역구'] = '은평구'
df_eunpyeong_crack.set_index('지역구', inplace=True)
df_eunpyeong_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 은평구  2018     845     585
# 은평구  2019     877     627
# 은평구  2020     968     532
# 은평구  2021     775     357

# %%
# 강북구
df_gangbuk_crack = pd.read_csv(os.path.join(base_path, 'gangbuk_crack.csv'))
df_gangbuk_crack.drop(['흡연부스설치수', '데이터기준일자'], axis=1, inplace=True)
df_gangbuk_crack.rename(columns={'흡연민원' :'흡연민원건수', '흡연단속' : '흡연단속건수'}, inplace=True)
df_gangbuk_crack['지역구'] = '강북구'
df_gangbuk_crack.set_index('지역구', inplace=True)
df_gangbuk_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 강북구  2014       0     817
# 강북구  2015     158     440
# 강북구  2016     194     506
# 강북구  2017     174     425
# 강북구  2018     266     264

# %%
# 강서구
df_kangseo_crack = pd.read_csv(os.path.join(base_path, 'kangseo_crack.csv'))
df_kangseo_crack.drop(['흡연구역 수'], axis=1, inplace=True)
df_kangseo_crack.rename(columns={'년도' : '연도', '흡연민원 건수' : '흡연민원건수', '흡연단속 건수' : '흡연단속건수'}, inplace=True)
df_kangseo_crack['지역구'] = '강서구'
df_kangseo_crack.set_index('지역구', inplace=True)
df_kangseo_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 강서구  2017     460    1099
# 강서구  2018     526    1294
# 강서구  2019     357     876

# %%
# 영등포구
df_yeongdeungpo_crack = pd.read_csv(os.path.join(base_path, 'yeongdeungpo_crack.csv'))
df_yeongdeungpo_crack.drop(['데이터기준일자'], axis=1, inplace=True)
df_yeongdeungpo_crack.rename(columns={'연도' : 'year', '민원건수' : '흡연민원건수', '단속건수' : '흡연단속건수'}, inplace=True)
df_yeongdeungpo_crack['nyear'] = df_yeongdeungpo_crack.year.transform(lambda year: str(year)[:4])
df_yeongdeungpo_crack.drop(['year'], axis=1, inplace=True)
df_yeongdeungpo_crack  = df_yeongdeungpo_crack[['nyear', '흡연민원건수', '흡연단속건수']]
df_yeongdeungpo_crack.rename(columns={'nyear' : '연도'}, inplace=True)
df_yeongdeungpo_crack['지역구'] = '영등포구'
df_yeongdeungpo_crack.set_index('지역구', inplace=True)
df_yeongdeungpo_crack
# Out:
#         연도  흡연민원건수  흡연단속건수
# 지역구
# 영등포구  2015     490    4000
# 영등포구  2016     564    5370
# 영등포구  2017     568    6243
# 영등포구  2018     568    6278
# 영등포구  2019     987    9187
# 영등포구  2020     692    3618

# %%
# 중구
df_junggu_crack = pd.read_csv(os.path.join(base_path, 'junggu_crack.csv'))
df_junggu_crack.drop(['흡연인구비율', '흡연부스설치'], axis=1, inplace=True)
df_junggu_crack.rename(columns={'년도' : '연도', '흡연민원' : '흡연민원건수', '흡연단속' : '흡연단속건수'}, inplace=True)
df_junggu_crack['지역구'] = '중구'
df_junggu_crack.set_index('지역구', inplace=True)
df_junggu_crack
# Out:
#        연도  흡연민원건수   흡연단속
# 지역구
# 중구   2012      27      74
# 중구   2013      60     258
# 중구   2014     243     351
# 중구   2015     343     676
# 중구   2016     756    1632

# %%
# 동대문구
df_dongdaemun_crack = pd.read_csv(os.path.join(base_path, 'dongdaemun_crack.csv'))
df_dongdaemun_crack = df_dongdaemun_crack[4:]
df_dongdaemun_crack.drop(['19-29세', '30-39세', '40-49세', '50-59세', '60-69세', '70세 이상', '데이터기준일자'], axis=1, inplace=True)
df_dongdaemun_crack = df_dongdaemun_crack.astype(int)
df_dongdaemun_crack.rename(columns={'흡연민원' : '흡연민원건수', '흡연단속' : '흡연단속건수'}, inplace=True)
df_dongdaemun_crack['지역구'] = '동대문구'
df_dongdaemun_crack.set_index('지역구', inplace=True)
df_dongdaemun_crack
# Out:
#         연도  흡연민원건수  흡연단속건수
# 지역구
# 동대문구  2012       8      56
# 동대문구  2013      32     149
# 동대문구  2014     163     261
# 동대문구  2015     152      97
# 동대문구  2016     141     336
# 동대문구  2017     217    1133
# 동대문구  2018     226     801
# 동대문구  2019     353     505
# 동대문구  2020     563     658

# %%
# 마포구
df_mapo_crack = pd.read_csv(os.path.join(base_path, 'mapo_crack.csv'))
df_mapo_crack = df_mapo_crack.sort_values(by='연도')
df_mapo_crack.drop(['데이터기준일자'], axis=1, inplace=True)
df_mapo_crack.rename(columns={'흡연민원' : '흡연민원건수', '흡연단속' : '흡연단속건수'}, inplace=True)
df_mapo_crack['지역구'] = '마포구'
df_mapo_crack.set_index('지역구', inplace=True)
df_mapo_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 마포구  2012     234       9
# 마포구  2013     546       7
# 마포구  2014     829     774
# 마포구  2015     988     387
# 마포구  2016     685     362
# 마포구  2017    1101     444
# 마포구  2018    1147     366
# 마포구  2019    1857     330
# 마포구  2020    1372     265

# %%
# 중랑구
df_junglanggu_crack = pd.read_csv(os.path.join(base_path, 'junglanggu_crack.csv'))
df_junglanggu_crack.drop(['흡연부스현황(개수)누계'], axis=1, inplace=True)
df_junglanggu_crack.rename(columns={'흡연민원(건)' : '흡연민원건수', '흡연단속(건)' : '흡연단속건수'}, inplace=True)
df_junglanggu_crack['지역구'] = '중랑구'
df_junglanggu_crack.set_index('지역구', inplace=True)
df_junglanggu_crack
# Out:
#        연도  흡연민원건수  흡연단속건수
# 지역구
# 중랑구  2008       0       0
# 중랑구  2009       0       0
# 중랑구  2010       0       0
# 중랑구  2011       0       0
# 중랑구  2012       0       0
# 중랑구  2013     245      13
# 중랑구  2014     446     928
# 중랑구  2015     587     625
# 중랑구  2016     673     391
# 중랑구  2017     796     354
# 중랑구  2018     861     233
# 중랑구  2019     470     712
# 중랑구  2020     705     182

# %%
# all concat인데 쓸일없을듯
df_crack = pd.concat([df_dongdaemun_crack, df_yeongdeungp_crack, df_kangseo_crack, df_gangbuk_crack, df_kwangjjin_crack, df_kwanak_crack, df_guro_crack, df_gangnam_crack, df_seocho_crack, df_songpa_crack, df_yangcheon_crack, df_dongjak_crack, df_eunpyeong_crack])
df_crack
# Out:
#         연도 흡연민원건수 흡연단속건수
# 영등포구  2015    490   4000
# 영등포구  2016    564   5370
# 영등포구  2017    568   6243
# 영등포구  2018    568   6278
# 영등포구  2019    987   9187
# ...    ...    ...    ...
# 동작구   2021    400    169
# 은평구   2018    845    585
# 은평구   2019    877    627
# 은평구   2020    968    532
# 은평구   2021    775    357
#
# [76 rows x 3 columns]

# %%
# Out:
# 지역구
# 송파구        0
# 송파구      910
# 송파구    1,918
# 송파구    2,773
# 송파구    2,561
# 송파구    2,487
# 송파구    2,332
# 송파구    3,572
# 송파구    2,529
# 송파구    3,236
# Name: 흡연단속건수, dtype: object

# %%
# 시각화 예시
fig, axes = plt.subplots(5,3, figsize=(20,32))
df_kwanak_crack.plot(ax=axes[0,0], kind="bar", x="연도", title="관악구")
df_dongjak_crack.plot(ax=axes[0,1], kind="bar", x="연도", title="동작구")
df_gangnam_crack.plot(ax=axes[0,2], kind="bar", x="연도", title="강남구")
df_guro_crack.plot(ax=axes[1,0], kind="bar", x="연도", title="구로구")
df_kwangjjin_crack.plot(ax=axes[1,1], kind="bar", x="연도", title="광진구")
df_seocho_crack.plot(ax=axes[1,2], kind="bar", x="연도", title="서초구")
df_songpa_crack.plot(ax=axes[2,0], kind="bar", x="연도", title="송파구")
df_yangcheon_crack.plot(ax=axes[2,1], kind="bar", x="연도", title="양천구")
df_gangbuk_crack.plot(ax=axes[2,2], kind="bar", x="연도", title="강북구")
df_kangseo_crack.plot(ax=axes[3,0], kind="bar", x="연도", title="강서구")
df_yeongdeungpo_crack.plot(ax=axes[3,1], kind="bar", x="연도", title="영등포구")
df_junggu_crack.plot(ax=axes[3,2], kind="bar", x="연도", title="중구")
df_dongdaemun_crack.plot(ax=axes[4,0], kind="bar", x="연도", title="동대문구")
df_mapo_crack.plot(ax=axes[4,1], kind="bar", x="연도", title="마포구")
df_junglanggu_crack.plot(ax=axes[4,2], kind="bar", x="연도", title="중랑구")
plt.set_xticks([0,250,500,700,1000])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-411-278a27ad2d8c> in <module>
#      16 df_mapo_crack.plot(ax=axes[4,1], kind="bar", x="연도", title="마포구")
#      17 df_junglanggu_crack.plot(ax=axes[4,2], kind="bar", x="연도", title="중랑구")
# ---> 18 plt.set_xticks([0,250,500,700,1000])
#      19
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xticks'

# %%
# 합쳐진데이터
base_path1 = r'C:\Users\grand\Desktop\smoking'
