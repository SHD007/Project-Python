# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
import pandas as pd
import numpy as np
import os
# %matplotlib inline

try : 
    if platform.system() == 'Windows':
    # 윈도우인 경우
        font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
        rc('font', family=font_name)
    else:    
    # Mac 인 경우
        rc('font', family='AppleGothic')
except : 
    pass
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
base_path=r'C:\Users\grand\Desktop\smoking\nonsmoking_place'

# %%
non_dobong_place = pd.read_csv(os.path.join(base_path, 'non_dobong_place.csv'))
non_dobong_place['금연구역구분'].unique()
# Out:
# array(['지하철 역사'], dtype=object)

# %%
non_dongdaemun_place = pd.read_csv(os.path.join(base_path, 'non_dongdaemun_place.csv'))
non_dongdaemun_place
# Out:
#             금연구역명           금연구역범위상세    시도명  시군구명 금연구역구분  \
# 0           간데메공원               공원전체  서울특별시  동대문구   금연공원
# 1        꿈동산어린이공원               공원전체  서울특별시  동대문구   금연공원
# 2            내길공원               공원전체  서울특별시  동대문구   금연공원
# 3       느티나무어린이공원               공원전체  서울특별시  동대문구   금연공원
# 4         늘봄어린이공원               공원전체  서울특별시  동대문구   금연공원
# ..            ...                ...    ...   ...    ...
# 145           용두역  지하철 출입구로부터 10m 이내  서울특별시  동대문구   지하철역
# 146          답십리역  지하철 출입구로부터 10m 이내  서울특별시  동대문구   지하철역
# 147          장한평역  지하철 출입구로부터 10m 이내  서울특별시  동대문구   지하철역
# 148          고려대역  지하철 출입구로부터 10m 이내  서울특별시  동대문구   지하철역
# 149  구청과 보건소 연결통로            연결통로 전체  서울특별시  동대문구   금연구역
#
#                    금연구역지정근거명   금연구역면적   위반과태료      위반신고전화번호  \
# 0    서울특별시 동대문구 간접흡연 피해방지 조례  15180.0  100000  02-2127-4632
# 1    서울특별시 동대문구 간접흡연 피해방지 조례   1571.0  100000  02-2127-4632
# 2    서울특별시 동대문구 간접흡연 피해방지 조례    515.0  100000  02-2127-4632
# ...

# %%
non_dongjak_place = pd.read_csv(os.path.join(base_path, 'non_dongjak_place.csv'))
non_dongjak_place
# Out:
#                       금연구역명                       금연구역범위상세    시도명 시군구명  \
# 0                      동작구청                     건물 및 대지 전체  서울특별시  동작구
# 1                  동작문화복지센터                     건물 및 대지 전체  서울특별시  동작구
# 2                 동작구청 임차청사                     건물 및 대지 전체  서울특별시  동작구
# 3                     동작구의회                     건물 및 대지 전체  서울특별시  동작구
# 4               노량진제1동 주민센터                     건물 및 대지 전체  서울특별시  동작구
# ..                      ...                            ...    ...  ...
# 406   성남고등학교 통학로(학교주변 금연거리)                  대방동길 보행로 443m  서울특별시  동작구
# 407   영화초등학교 통학로(학교주변 금연거리)                 등용로8길 보행로 165m  서울특별시  동작구
# 408  중대부속중학교 통학로(학교주변 금연거리)          서달로(정문~천사약국) 보행로 724m  서울특별시  동작구
# 409   서울삼성학교 통학로(학교주변 금연거리)                양녕로30길 보행로 314m  서울특별시  동작구
# 410    문창중학교 통학로(학교주변 금연거리)  여의대방로22길, 22가길, 22나길 보행로 516m  서울특별시  동작구
#
#            금연구역구분                   금연구역지정근거명  금연구역면적   위반과태료     위반신고전화번호  \
# ...

# %%
non_eunpyeong_place = pd.read_csv(os.path.join(base_path, 'non_eunpyeong_place.csv'))
non_eunpyeong_place
# Out:
#                      금연구역명        금연구역범위상세    시도명 시군구명  \
# 0             3POP PC CAFE             PC방  서울특별시  은평구
# 1        비원PC방,비투박스코인노래연습장             PC방  서울특별시  은평구
# 2                   웹시티PC방             PC방  서울특별시  은평구
# 3                    홀릭PC방             PC방  서울특별시  은평구
# 4               집PC클럽(응암점)             PC방  서울특별시  은평구
# ...                    ...             ...    ...  ...
# 8683       구산역 지하철 출입구 4개소  지하철 출입구 10m 이내  서울특별시  은평구
# 8684       새절역 지하철 출입구 4개소  지하철 출입구 10m 이내  서울특별시  은평구
# 8685       증산역 지하철 출입구 4개소  지하철 출입구 10m 이내  서울특별시  은평구
# 8686  디지털미디어시티역지하철 출입구 4개소  지하철 출입구 10m 이내  서울특별시  은평구
# 8687       수색역 지하철 출입구 1개소  지하철 출입구 10m 이내  서울특별시  은평구
#
#                              금연구역구분              금연구역지정근거명  금연구역면적   위반과태료  \
# 0     게임산업진흥에관한법률에따른 인터넷컴퓨터게임시설제공업소             국민건강증진법제9조     NaN  100000
# 1     게임산업진흥에관한법률에따른 인터넷컴퓨터게임시설제공업소             국민건강증진법제9조     NaN  100000
# 2     게임산업진흥에관한법률에따른 인터넷컴퓨터게임시설제공업소             국민건강증진법제9조     NaN  100000
# ...

# %%
non_gangbuk_place = pd.read_csv(os.path.join(base_path, 'non_gangbuk_place.csv'))
non_gangbuk_place
# Out:
#                금연구역명   금연구역범위상세    시도명 시군구명      금연구역구분 금연구역지정근거명  금연구역면적  \
# 0         SG스크린골프수유점  제육시설면적 전체  서울특별시  강북구  가상체험 체육시설업   국민건강증진법    1.00
# 1             한일골프스쿨  제육시설면적 전체  서울특별시  강북구      골프연습장업   국민건강증진법    1.00
# 2             삼성골프클럽  제육시설면적 전체  서울특별시  강북구      골프연습장업   국민건강증진법    1.00
# 3           럭키 골프 클럽  제육시설면적 전체  서울특별시  강북구      골프연습장업   국민건강증진법    1.00
# 4            드림골프스토리  제육시설면적 전체  서울특별시  강북구      골프연습장업   국민건강증진법    1.00
# ...              ...        ...    ...  ...         ...       ...     ...
# 6692  와플대학 미아사거리역캠퍼스   음식점면적 전체  서울특별시  강북구       휴게음식점   국민건강증진법   29.15
# 6693      영수네 만두 미아점   음식점면적 전체  서울특별시  강북구       휴게음식점   국민건강증진법   30.60
# 6694              스톤   음식점면적 전체  서울특별시  강북구       휴게음식점   국민건강증진법   76.00
# 6695     CU SK북한산시티점   음식점면적 전체  서울특별시  강북구       휴게음식점   국민건강증진법    3.30
# 6696             포너드   음식점면적 전체  서울특별시  강북구       휴게음식점   국민건강증진법   29.76
#
#        위반과태료     위반신고전화번호                                           소재지도로명주소  \
# ...

# %%
non_gangdong_place = pd.read_csv(os.path.join(base_path, 'non_gangdong_place.csv'))
non_gangdong_place
# Out:
#               금연구역명   금연구역범위상세    시도명 시군구명 금연구역구분   금연구역지정근거명  금연구역면적   위반과태료  \
# 0                강덕       공원전체  서울특별시  강동구     공원  국민건강증진법제9조   46699  100000
# 1                강일       공원전체  서울특별시  강동구     공원  국민건강증진법제9조   34591  100000
# 2                게내       공원전체  서울특별시  강동구     공원  국민건강증진법제9조    1500  100000
# 3                고명       공원전체  서울특별시  강동구     공원  국민건강증진법제9조     545  100000
# 4              고분다리       공원전체  서울특별시  강동구     공원  국민건강증진법제9조    1622  100000
# ..              ...        ...    ...  ...    ...         ...     ...     ...
# 92           둔촌종합상가  그밖의 대규모점포  서울특별시  강동구  대규모점포  국민건강증진법제9조   11069  100000
# 93  둔촌시장주상복합(파크프라자)  그밖의 대규모점포  서울특별시  강동구  대규모점포  국민건강증진법제9조   23909  100000
# 94    강동한신휴플러스 주상복합  그밖의 대규모점포  서울특별시  강동구  대규모점포  국민건강증진법제9조   27099  100000
# 95        이안강동 주상복합  그밖의 대규모점포  서울특별시  강동구  대규모점포  국민건강증진법제9조   15437  100000
# 96           동서울오네뜨  그밖의 대규모점포  서울특별시  강동구  대규모점포  국민건강증진법제9조    4715  100000
#
# ...

# %%
non_gangnam_place = pd.read_csv(os.path.join(base_path, 'non_gangnam_place.csv'))
non_gangnam_place
# Out:
#                           금연구역명                    금연구역범위상세    시도명 시군구명  \
# 0                        압구정중학교          출입문으로부터 직선거리 50m까지  서울특별시  강남구
# 1                         언북중학교          출입문으로부터 직선거리 50m까지  서울특별시  강남구
# 2                         언주중학교          출입문으로부터 직선거리 50m까지  서울특별시  강남구
# 3                         역삼중학교          출입문으로부터 직선거리 50m까지  서울특별시  강남구
# 4                         은성중학교          출입문으로부터 직선거리 50m까지  서울특별시  강남구
# ..                          ...                         ...    ...  ...
# 449        도곡중학교 도록로38길 보도 및 차도    도곡중학교 도록로38길 보도 및 차도 55m  서울특별시  강남구
# 450  도곡중학교 주변 강남세브란스병원 후문 입구 전체  도곡중학교 주변 강남세브란스병원 후문 입구 전체  서울특별시  강남구
# 451                      역삼장미공원                        시설전체  서울특별시  강남구
# 452                    개포은행나무공원                        시설전체  서울특별시  강남구
# 453                      개포목련공원                        시설전체  서울특별시  강남구
#
#      금연구역구분                             금연구역지정근거명  금연구역면적   위반과태료  \
# ...

# %%
non_gangseo_place = pd.read_csv(os.path.join(base_path, 'non_gangseo_place.csv'))
non_gangseo_place
# Out:
#       금연구역명               금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0    가양초등학교  학교출입문으로부터 직선거리 50m 이내  서울특별시  강서구  학교절대정화구역
# 1    등서초등학교  학교출입문으로부터 직선거리 50m 이내  서울특별시  강서구  학교절대정화구역
# 2    등양초등학교  학교출입문으로부터 직선거리 50m 이내  서울특별시  강서구  학교절대정화구역
# 3    등원초등학교  학교출입문으로부터 직선거리 50m 이내  서울특별시  강서구  학교절대정화구역
# 4    등촌초등학교  학교출입문으로부터 직선거리 50m 이내  서울특별시  강서구  학교절대정화구역
# ..      ...                    ...    ...  ...       ...
# 554     새 싹               공원 시설 전체  서울특별시  강서구    실외금연구역
# 555     방화동               공원 시설 전체  서울특별시  강서구    실외금연구역
# 556     등촌동               공원 시설 전체  서울특별시  강서구    실외금연구역
# 557   염창동 2               공원 시설 전체  서울특별시  강서구    실외금연구역
# 558  마곡소공원2               공원 시설 전체  서울특별시  강서구    실외금연구역
#
#                       금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0    서울특별시 강서구 간접흡연 피해방지 조례 제5조     NaN  100000  02-2600-5846
# 1    서울특별시 강서구 간접흡연 피해방지 조례 제5조     NaN  100000  02-2600-5846
# 2    서울특별시 강서구 간접흡연 피해방지 조례 제5조     NaN  100000  02-2600-5846
# ...

# %%
non_geumcheon_place = pd.read_csv(os.path.join(base_path, 'non_geumcheon_place.csv'))
non_geumcheon_place
# Out:
#            금연구역명                 금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0    가산디지털단지역 주변   7번 출입구로부터 90m 구간 거리 전체  서울특별시  금천구      금연거리
# 1    가산디지털단지역 주변    5,6번 출구 양방향 (280m) 구간  서울특별시  금천구      금연거리
# 2    가산디지털단지역 주변  2,3,4번 출구 양방향 (500m) 구간  서울특별시  금천구      금연거리
# 3         가산디지털역          1번출입구로부터 10m 이내  서울특별시  금천구   지하철 출입구
# 4            독산역          2번출입구로부터 10m 이내  서울특별시  금천구   지하철 출입구
# ..           ...                      ...    ...  ...       ...
# 421     구립별솔어린이집          어린이집,유치원 경계 10m  서울특별시  금천구  어린이집,유치원
# 422     한신붕붕어린이집          어린이집,유치원 경계 10m  서울특별시  금천구  어린이집,유치원
# 423   구립해야해야어린이집          어린이집,유치원 경계 10m  서울특별시  금천구  어린이집,유치원
# 424     구립슬기어린이집          어린이집,유치원 경계 10m  서울특별시  금천구  어린이집,유치원
# 425      예사랑어린이집          어린이집,유치원 경계 10m  서울특별시  금천구  어린이집,유치원
#
#             금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0    금천구 간접흡연 피해방지 조례     NaN  100000  02-2627-2617
# 1    금천구 간접흡연 피해방지 조례     NaN  100000  02-2627-2617
# ...

# %%
non_guro_place = pd.read_csv(os.path.join(base_path, 'non_guro_place.csv'))
non_guro_place
# Out:
#                       금연구역명           금연구역범위상세    시도명 시군구명   금연구역구분  \
# 0                햇빛어린이집 놀이터               시설전체  서울특별시  구로구  어린이놀이시설
# 1     구로삼성래미안아파트 116동 앞 놀이터               시설전체  서울특별시  구로구  어린이놀이시설
# 2     구로삼성래미안아파트 114동 앞 놀이터               시설전체  서울특별시  구로구  어린이놀이시설
# 3     구로삼성래미안아파트 104동 앞 놀이터               시설전체  서울특별시  구로구  어린이놀이시설
# 4                하얀어린이집 놀이터               시설전체  서울특별시  구로구  어린이놀이시설
# ...                     ...                ...    ...  ...      ...
# 2582             구로중학교 주변거리  담장 주변 보행자 도로 540m  서울특별시  구로구     금연거리
# 2583            고척월드메르디앙아파트     복도계단엘리베이터지하주차장  서울특별시  구로구     공동주택
# 2584         항동제일풍경채포레스트아파트     복도계단엘리베이터지하주차장  서울특별시  구로구     공동주택
# 2585           항동하버라인4단지아파트     복도계단엘리베이터지하주차장  서울특별시  구로구     공동주택
# 2586         항동 하버라인2단지 아파트     복도계단엘리베이터지하주차장  서울특별시  구로구     공동주택
#
#                        금연구역지정근거명  금연구역면적   위반과태료     위반신고전화번호  \
# 0                국민건강증진법 제9조 제4항       0  100000  02-860-3225
# ...

# %%
non_jongro_place = pd.read_csv(os.path.join(base_path, 'non_jongro_place.csv'))
non_jongro_place
# Out:
#                   금연구역명                      금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0             새문안로2길 일대                     새문안로2길 일대  서울특별시  종로구        거리
# 1               흥인지문 공원                       흥인지문 공원  서울특별시  종로구      도시공원
# 2              옥인어린이 공원                      옥인어린이 공원  서울특별시  종로구      도시공원
# 3              무악어린이 공원                      무악어린이 공원  서울특별시  종로구      도시공원
# 4                  부암튼튼                          부암튼튼  서울특별시  종로구      도시공원
# ..                  ...                           ...    ...  ...       ...
# 327               화정박물관  버스정류소 승차대 또는 표지판 경계로부터 10m이내  서울특별시  종로구  가로변버스정류소
# 328        명륜동2가.성균관대입구  버스정류소 승차대 또는 표지판 경계로부터 10m이내  서울특별시  종로구  가로변버스정류소
# 329              혜화동로터리  버스정류소 승차대 또는 표지판 경계로부터 10m이내  서울특별시  종로구  가로변버스정류소
# 330    혜화역,동성중고(장면총리가옥)  버스정류소 승차대 또는 표지판 경계로부터 10m이내  서울특별시  종로구  가로변버스정류소
# 331  혜화역,서울연극센터(장면총리가옥)  버스정류소 승차대 또는 표지판 경계로부터 10m이내  서울특별시  종로구  가로변버스정류소
#
# ...

# %%
non_junggu_place = pd.read_csv(os.path.join(base_path, 'non_junggu_place.csv'))
non_junggu_place
# Out:
#            금연구역명                     금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0      CJ키즈빌어린이집            시설의경계선으로부터 10m 이내  서울특별시   중구      어린이집
# 1      GKL행복어린이집            시설의경계선으로부터 10m 이내  서울특별시   중구      어린이집
# 2    IBK 참좋은어린이집            시설의경계선으로부터 10m 이내  서울특별시   중구      어린이집
# 3      LG서울역빌딩주변  서울특별시 중구 LG서울역빌딩 주변 230m 거리  서울특별시   중구        거리
# 4      LG서울역어린이집            시설의경계선으로부터 10m 이내  서울특별시   중구      어린이집
# ..           ...                          ...    ...  ...       ...
# 346        후암삼거리           버스정류소 승차대로부터 10m이내  서울특별시   중구  가로변버스정류소
# 347       흥인초등학교            학교 출입문으로부터 50m 이내  서울특별시   중구  학교절대정화구역
# 348   흥인초등학교 통학로            학생 통학로 일대 190m 거리  서울특별시   중구        거리
# 349         힐튼호텔           버스정류소 승차대로부터 10m이내  서울특별시   중구  가로변버스정류소
# 350         힐튼호텔           버스정류소 승차대로부터 10m이내  서울특별시   중구  가로변버스정류소
#
#                  금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0    서울특별시 중구 간접흡연 피해방지 조례     NaN  100000  02-3396-5672
# ...

# %%
non_jungrang_place = pd.read_csv(os.path.join(base_path, 'non_jungrang_place.csv'))
non_jungrang_place
# Out:
#         금연구역명      금연구역범위상세    시도명 시군구명 금연구역구분  \
# 0    용마도시자연공원         공원 전역  서울특별시  중랑구     공원
# 1     봉화산근린공원         공원 전역  서울특별시  중랑구     공원
# 2      능산근린공원         공원 전역  서울특별시  중랑구     공원
# 3    신내어울근린공원         공원 전역  서울특별시  중랑구     공원
# 4          면목         공원 전역  서울특별시  중랑구     공원
# ..        ...           ...    ...  ...    ...
# 746     동성유치원  경계로부터 10m 이내  서울특별시  중랑구    유치원
# 747   서울새솔유치원  경계로부터 10m 이내  서울특별시  중랑구    유치원
# 748    새아랑유치원  경계로부터 10m 이내  서울특별시  중랑구    유치원
# 749     영은유치원  경계로부터 10m 이내  서울특별시  중랑구    유치원
# 750     예원유치원  경계로부터 10m 이내  서울특별시  중랑구    유치원
#
#                            금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0    서울특별시 중랑구 간접흡연 피해방지 조례 5조 1항 6호     100  100000  02-2094-0864
# 1    서울특별시 중랑구 간접흡연 피해방지 조례 5조 1항 6호     100  100000  02-2094-0864
# 2    서울특별시 중랑구 간접흡연 피해방지 조례 5조 1항 6호     100  100000  02-2094-0864
# 3    서울특별시 중랑구 간접흡연 피해방지 조례 5조 1항 6호     100  100000  02-2094-0864
# ...

# %%
non_kwanak_place = pd.read_csv(os.path.join(base_path, 'non_kwanak_place.csv'))
non_kwanak_place
# Out:
#                 금연구역명                                금연구역범위상세    시도명 시군구명  \
# 0             123어린이집                        시설 경계선으로부터 10m이내  서울특별시  관악구
# 1          24시간연세어린이집                        시설 경계선으로부터 10m이내  서울특별시  관악구
# 2              가나어린이집                        시설 경계선으로부터 10m이내  서울특별시  관악구
# 3              가람어린이집                        시설 경계선으로부터 10m이내  서울특별시  관악구
# 4           감성아이 어린이집                        시설 경계선으로부터 10m이내  서울특별시  관악구
# ..                ...                                     ...    ...  ...
# 682   서울대입구역~구청간 금연거리                    서울대입구역2,3출구~구청간 양측보도  서울특별시  관악구
# 683      신림역~봉림교 금연거리                      신림역4,5출구~봉림교간 양측보도  서울특별시  관악구
# 684  영락의료과학고 통학로 금연거리  영락어린이공원~학교시설경계정문~쑥고개로16길과 청룡10길 교차점 보도  서울특별시  관악구
# 685   당곡고등학교 통학로 금연건리              구간경계~연희빌라 앞연희빌라 앞~성원홈아파트 앞  서울특별시  관악구
# 686      신봉초 통학로 금연거리       청운빌딩앞~양녕로6다길 3 뒤이마트24 앞~무지개언약교회 앞  서울특별시  관악구
#
#     금연구역구분                           금연구역지정근거명  금연구역면적   위반과태료     위반신고전화번호  \
# ...

# %%
non_kwangjin_place = pd.read_csv(os.path.join(base_path, 'non_kwangjin_place.csv'))
non_kwangjin_place
# Out:
#           금연구역명 금연구역범위상세    시도명 시군구명    금연구역구분    금연구역지정근거명  금연구역면적   위반과태료  \
# 0         광진우체국     시설전체  서울특별시  광진구   공공기관 청사  국민건강증진법 제9조     NaN  100000
# 1         광진소방서     시설전체  서울특별시  광진구   공공기관 청사  국민건강증진법 제9조     NaN  100000
# 2         광진경찰서     시설전체  서울특별시  광진구   공공기관 청사  국민건강증진법 제9조     NaN  100000
# 3    광진구 시설관리공단     시설전체  서울특별시  광진구  지방공기업 청사  국민건강증진법 제9조     NaN  100000
# 4    광장동 주민자치센터     시설전체  서울특별시  광진구   자치단체 청사  국민건강증진법 제9조     NaN  100000
# ..          ...      ...    ...  ...       ...          ...     ...     ...
# 222    대원여자고등학교     시설전체  서울특별시  광진구      고등학교  국민건강증진법 제9조     NaN  100000
# 223   대원외국어고등학교     시설전체  서울특별시  광진구      고등학교  국민건강증진법 제9조     NaN  100000
# 224    장로회신학대학교     시설전체  서울특별시  광진구       대학교  국민건강증진법 제9조     NaN  100000
# 225       세종대학교     시설전체  서울특별시  광진구       대학교  국민건강증진법 제9조     NaN  100000
# 226       건국대학교     시설전체  서울특별시  광진구       대학교  국민건강증진법 제9조     NaN  100000
#
# ...

# %%
non_mapo_place = pd.read_csv(os.path.join(base_path, 'non_mapo_place.csv'))
non_mapo_place
# Out:
#                  금연구역명 금연구역범위상세    시도명 시군구명 금연구역구분   금연구역지정근거명  금연구역면적  \
# 0                마포소방서     시설전체  서울특별시  마포구     청사  국민건강증진법제9조     NaN
# 1               신수안전센터     시설전체  서울특별시  마포구     청사  국민건강증진법제9조     NaN
# 2        염리안전센터(마포소방서)     시설전체  서울특별시  마포구     청사  국민건강증진법제9조     NaN
# 3               서교안전센터     시설전체  서울특별시  마포구     청사  국민건강증진법제9조     NaN
# 4               성산안전센터     시설전체  서울특별시  마포구     청사  국민건강증진법제9조     NaN
# ...                ...      ...    ...  ...    ...         ...     ...
# 12230           아현스포렉스     시설전체  서울특별시  마포구   체육시설     국민건강증진법     NaN
# 12231      신석웰니스 스포츠센터     시설전체  서울특별시  마포구   체육시설     국민건강증진법     NaN
# 12232  스탠포드호텔서울 휘트니스센터     시설전체  서울특별시  마포구   체육시설     국민건강증진법     NaN
# 12233           한국우진학교     시설전체  서울특별시  마포구   체육시설     국민건강증진법     NaN
# 12234           버닝 복싱짐     시설전체  서울특별시  마포구   체육시설     국민건강증진법     NaN
#
#         위반과태료      위반신고전화번호  \
# 0      100000  02-3153-9054
# 1      100000  02-3153-9054
# ...

# %%
non_nowon_place = pd.read_csv(os.path.join(base_path, 'non_nowon_place.csv'))
non_nowon_place
# Out:
#                          금연구역명  \
# 0                   녹천역 1번 출입구
# 1          월계우남아파트어린이놀이터(102동)
# 2           월계우남아파트어린이놀이터(관리동)
# 3                          우이천
# 4                 동신아파트 어린이놀이터
# ..                         ...
# 959  수락리버시티3단지아파트 어린이놀이터(308동)
# 960                 상계장암지구근린공원
# 961                        동일로
# 962                     석계문화공원
# 963             당고개역 3번 출입구 쉼터
#
#                                               금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0                                          출입구로 부터 10m  서울특별시  노원구   지하철 출입구
# 1                                                 시설부지  서울특별시  노원구  어린이 놀이시설
# 2                                                 시설부지  서울특별시  노원구  어린이 놀이시설
# 3    좌안(2.65km) 초안교~석계역 공영주차장 전(제방 상단 도로변 보도 및 데크 포...  서울특별시  노원구       하천변
# 4                                                 시설부지  서울특별시  노원구  어린이 놀이시설
# ..                                                 ...    ...  ...       ...
# ...

# %%
non_seocho_place = pd.read_csv(os.path.join(base_path, 'non_seocho_place.csv'))
non_seocho_place
# Out:
#                금연구역명                           금연구역범위상세    시도명 시군구명 금연구역구분  \
# 0         KTDS서초어린이집  건축물 경계선 반경 10m이내의 도로법에 의한 보도 및 차도  서울특별시  서초구   어린이집
# 1    KT연구개발센터꿈나무어린이집  건축물 경계선 반경 10m이내의 도로법에 의한 보도 및 차도  서울특별시  서초구   어린이집
# 2       LG전자강남센터어린이집  건축물 경계선 반경 10m이내의 도로법에 의한 보도 및 차도  서울특별시  서초구   어린이집
# 3          가나안샘터어린이집  건축물 경계선 반경 10m이내의 도로법에 의한 보도 및 차도  서울특별시  서초구   어린이집
# 4        경기 몬테소리어린이집  건축물 경계선 반경 10m이내의 도로법에 의한 보도 및 차도  서울특별시  서초구   어린이집
# ..               ...                                ...    ...  ...    ...
# 775      지혜의 숲 작은도서관                               시설전체  서울특별시  서초구    도서관
# 776     풍경이 있는 작은도서관                               시설전체  서울특별시  서초구    도서관
# 777        하늘샘 작은도서관                               시설전체  서울특별시  서초구    도서관
# 778       양재 너구리 도서관                               시설전체  서울특별시  서초구    도서관
# 779         IT로열린도서관                               시설전체  서울특별시  서초구    도서관
#
# ...

# %%
non_seodaemun_place = pd.read_csv(os.path.join(base_path, 'non_seodaemun_place.csv'))
non_seodaemun_place
# Out:
#             금연구역명            금연구역범위상세    시도명  시군구명 금연구역구분     금연구역지정근거명  \
# 0          남가좌파출소             건물 및 부지  서울특별시  서대문구     청사      국민건강 증진법
# 1      남가좌1동 주민센터             건물 및 부지  서울특별시  서대문구     청사      국민건강 증진법
# 2      남가좌2동 주민센터             건물 및 부지  서울특별시  서대문구     청사      국민건강 증진법
# 3        정담은 푸드마켓             건물 및 부지  서울특별시  서대문구     청사      국민건강 증진법
# 4        신촌동 주민센터             건물 및 부지  서울특별시  서대문구     청사      국민건강 증진법
# ...           ...                 ...    ...   ...    ...           ...
# 7194  쌍용 스윗닷홈 아파트  지하 주차장.복도실.계단실 ev실  서울특별시  서대문구     주택       국민건강증진법
# 7195   e편한세상신촌아파트  지하 주차장.복도실.계단실 ev실  서울특별시  서대문구     주택       국민건강증진법
# 7196   북가좌동 미다스 빌        복도실.계단실. ev실  서울특별시  서대문구     주택       국민건강증진법
# 7197       연가초등학교  출입구로 부터 50m이내.부지전체  서울특별시  서대문구  초중등학교       국민건강증진법
# 7198         영천시장                 시장내  서울특별시  서대문구   전통시장  서대문구 간접흡연 조례
#
#      금연구역면적   위반과태료     위반신고전화번호               소재지도로명주소              소재지지번주소  \
# ...

# %%
non_seongbuk_place = pd.read_csv(os.path.join(base_path, 'non_seongbuk_place.csv'))
non_seongbuk_place
# Out:
#       금연구역명 금연구역범위상세    시도명 시군구명 금연구역구분                  금연구역지정근거명  금연구역면적  \
# 0        성북     공원전체  서울특별시  성북구   도시공원  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 1        오동     공원전체  서울특별시  성북구   도시공원  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 2       개운산     공원전체  서울특별시  성북구   도시공원  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 3        청량     공원전체  서울특별시  성북구   도시공원  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 4       모랫말     공원전체  서울특별시  성북구   도시공원  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# ..      ...      ...    ...  ...    ...                        ...     ...
# 56      우이천    성북구지역  서울특별시  성북구     하천  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 57      중랑천    성북구지역  서울특별시  성북구     하천  서울특별시 성북구 금연환경조성및지원에관한 조례     NaN
# 58    하나로거리     거리일부  서울특별시  성북구     거리  서울특별시 성북구 금연환경조성및지원에관한 조례   240.0
# 59    아마존거리     거리일부  서울특별시  성북구     거리  서울특별시 성북구 금연환경조성및지원에관한 조례   520.0
# 60  길음뉴타운거리     거리일부  서울특별시  성북구     거리  서울특별시 성북구 금연환경조성및지원에관한 조례     2.5
#
# ...

# %%
non_seongdong_place  = pd.read_csv(os.path.join(base_path, 'non_seongdong_place.csv'))
non_seongdong_place
# Out:
#           금연구역명                 금연구역범위상세    시도명 시군구명 금연구역구분  \
# 0       견우어린이공원       표지판에 표시된 공원의 경계선 안  서울특별시  성동구   도시공원
# 1         경동유치원  학교시설전체 및 학교출입구로부터 50m이내  서울특별시  성동구     학교
# 2         경수중학교  학교시설전체 및 학교출입구로부터 50m이내  서울특별시  성동구     학교
# 3        경일고등학교  학교시설전체 및 학교출입구로부터 50m이내  서울특별시  성동구     학교
# 4    경일고등학교 통학로               경일고 주변 통학로  서울특별시  성동구     거리
# ..          ...                      ...    ...  ...    ...
# 129      한양초등학교  학교시설전체 및 학교출입구로부터 50m이내  서울특별시  성동구     학교
# 130    행당4구역소공원       표지판에 표시된 공원의 경계선 안  서울특별시  성동구   도시공원
# 131       행당중학교  학교시설전체 및 학교출입구로부터 50m이내  서울특별시  성동구     학교
# 132   행당한진타운 쉼터      행당한진타운 진입로 쉼터 경계선 안  서울특별시  성동구     기타
# 133       향림소공원       표지판에 표시된 공원의 경계선 안  서울특별시  성동구   도시공원
#
#                           금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0                 성동구간접흡연피해방지조례 제5조  1500.0  100000  02-2286-7032
# 1    국민건강증진법 제9조, 성동구간접흡연피해방지조례 제5조     NaN  100000  02-2286-7032
# ...

# %%
non_songpa_place  = pd.read_csv(os.path.join(base_path, 'non_songpa_place.csv'))
non_songpa_place
# Out:
#                금연구역명 금연구역범위상세    시도명 시군구명   금연구역구분    금연구역지정근거명  금연구역면적  \
# 0              고려한의원     시설전체  서울특별시  송파구     의료기관  국민건강증진법 제9조     NaN
# 1            서울휘안과의원     시설전체  서울특별시  송파구     의료기관  국민건강증진법 제9조     NaN
# 2            신세계치과의원     시설전체  서울특별시  송파구     의료기관  국민건강증진법 제9조     NaN
# 3              모정한의원     시설전체  서울특별시  송파구     의료기관  국민건강증진법 제9조     NaN
# 4            김민성치과의원     시설전체  서울특별시  송파구     의료기관  국민건강증진법 제9조     NaN
# ...              ...      ...    ...  ...      ...          ...     ...
# 2071       송파장애인문화협회     시설전체  서울특별시  송파구  장애인복지시설  국민건강증진법 제9조     NaN
# 2072    서울농아인협회 송파지부     시설전체  서울특별시  송파구  장애인복지시설  국민건강증진법 제9조     NaN
# 2073      한국시각장애인연합회     시설전체  서울특별시  송파구  장애인복지시설  국민건강증진법 제9조     NaN
# 2074  장애인취미교실(요리,볼링)     시설전체  서울특별시  송파구  장애인복지시설  국민건강증진법 제9조     NaN
# 2075     장애인편의시설지원센터     시설전체  서울특별시  송파구  장애인복지시설  국민건강증진법 제9조     NaN
#
#        위반과태료      위반신고전화번호                                소재지도로명주소  \
# ...

# %%
non_yangchun_place = pd.read_csv(os.path.join(base_path, 'non_yangchun_place.csv'))
non_yangchun_place
# Out:
#            금연구역명        금연구역범위상세    시도명 시군구명   금연구역구분  \
# 0     아랫말(어린이공원)           공원 전체  서울특별시  양천구     금연공원
# 1      오구(어린이공원)           공원 전체  서울특별시  양천구     금연공원
# 2      앞산(어린이공원)           공원 전체  서울특별시  양천구     금연공원
# 3      음골(어린이공원)           공원 전체  서울특별시  양천구     금연공원
# 4     동개울(어린이공원)           공원 전체  서울특별시  양천구     금연공원
# ..           ...             ...    ...  ...      ...
# 558     목동14단지상가  승강대로부터 10미터 이내  서울특별시  양천구  금연버스정류소
# 559  목동아파트1434동앞  승강대로부터 10미터 이내  서울특별시  양천구  금연버스정류소
# 560     신목초등학교입구  승강대로부터 10미터 이내  서울특별시  양천구  금연버스정류소
# 561     신정2동주민센터  승강대로부터 10미터 이내  서울특별시  양천구  금연버스정류소
# 562        신정교입구  승강대로부터 10미터 이내  서울특별시  양천구  금연버스정류소
#
#                     금연구역지정근거명  금연구역면적   위반과태료      위반신고전화번호  \
# 0    서울특별시 양천구 간접흡연 방지 조례 제5조   947.7  100000  02-2620-3899
# 1    서울특별시 양천구 간접흡연 방지 조례 제5조   738.4  100000  02-2620-3899
# 2    서울특별시 양천구 간접흡연 방지 조례 제5조  1050.5  100000  02-2620-3899
# 3    서울특별시 양천구 간접흡연 방지 조례 제5조   995.4  100000  02-2620-3899
# ...

# %%
non_yeongdeungpo_place = pd.read_csv(os.path.join(base_path, 'non_yeongdeungpo_place.csv'))
non_yeongdeungpo_place
# Out:
#                금연구역명             금연구역범위상세    시도명  시군구명  \
# 0           푸른나라(사립)  건물경계선으로부터 10m이내 보차도  서울특별시  영등포구
# 1             평화(사립)  건물경계선으로부터 10m이내 보차도  서울특별시  영등포구
# 2             평강(사립)  건물경계선으로부터 10m이내 보차도  서울특별시  영등포구
# 3            파랑새(사립)  건물경계선으로부터 10m이내 보차도  서울특별시  영등포구
# 4           파란나라(사립)  건물경계선으로부터 10m이내 보차도  서울특별시  영등포구
# ...              ...                  ...    ...   ...
# 1348      영등포역 4번 출구                 금연거리  서울특별시  영등포구
# 1349        한국거래소 주변                 금연거리  서울특별시  영등포구
# 1350  국제금융로, 국제금융로2길                 금연거리  서울특별시  영등포구
# 1351          여의대로2길                 금연거리  서울특별시  영등포구
# 1352          경인로88길                 금연거리  서울특별시  영등포구
#
#                        금연구역구분                 금연구역지정근거명  금연구역면적   위반과태료  \
# 0               유치원 및 어린이집 전체   서울특별시 영등포구 고시 제2014-18호     NaN  100000
# 1               유치원 및 어린이집 전체   서울특별시 영등포구 고시 제2014-18호     NaN  100000
# 2               유치원 및 어린이집 전체   서울특별시 영등포구 고시 제2014-18호     NaN  100000
# ...

# %%
non_yongsan_place = pd.read_csv(os.path.join(base_path, 'non_yongsan_place.csv'))
non_yongsan_place
# Out:
#        금연구역명                               금연구역범위상세    시도명 시군구명    금연구역구분  \
# 0   서울한남초등학교                      학교출입문으로부터 50미터 이내  서울특별시  용산구  학교절대보호구역
# 1     중경고등학교                      학교출입문으로부터 50미터 이내  서울특별시  용산구  학교절대보호구역
# 2   서울한강초등학교                      학교출입문으로부터 50미터 이내  서울특별시  용산구  학교절대보호구역
# 3      용강중학교                      학교출입문으로부터 50미터 이내  서울특별시  용산구  학교절대보호구역
# 4   서울남정초등학교                      학교출입문으로부터 50미터 이내  서울특별시  용산구  학교절대보호구역
# ..       ...                                    ...    ...  ...       ...
# 81    한남초등학교                      한남초 측면 단편보행로 150m  서울특별시  용산구       통학로
# 82    중경고등학교                            단편 보행로 200m  서울특별시  용산구       통학로
# 83    한강초등학교            정문앞 통학로 100m 및 맞은편 통학로 100m  서울특별시  용산구       통학로
# 84     용강중학교                  정문 및 후문 시설경계 통학로 310m  서울특별시  용산구       통학로
# 85    남정초등학교  정문앞 통학로 42m 및 우측 주통학로 98m,후문앞 통학로 85m  서울특별시  용산구       통학로
#
#                            금연구역지정근거명  금연구역면적  위반과태료      위반신고전화번호  \
# ...

# %%
df_non_smoking_place = pd.concat([non_yongsan_place, non_yeongdeungpo_place, non_yangchun_place, non_songpa_place, non_seongdong_place, non_seodaemun_place, non_seocho_place, non_nowon_place, non_mapo_place, 
                                 non_kwangjin_place, non_kwanak_place, non_jungrang_place, non_junggu_place, non_jongro_place, non_guro_place, non_geumcheon_place, non_gangseo_place, non_gangnam_place,
                                  non_gangdong_place, non_gangbuk_place, non_eunpyeong_place, non_dongjak_place, non_dongdaemun_place, non_dobong_place, non_seongbuk_place])
df_non_smoking_place.reset_index(drop=True, inplace=True)
#df_non_smoking_place.to_csv("non_smoking_place.csv")
df_non_smoking_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47874 entries, 0 to 47873
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   금연구역명      47874 non-null  object
#  1   금연구역범위상세   47874 non-null  object
#  2   시도명        47874 non-null  object
#  3   시군구명       47874 non-null  object
#  4   금연구역구분     47874 non-null  object
#  5   금연구역지정근거명  47874 non-null  object
#  6   금연구역면적     16880 non-null  object
#  7   위반과태료      47788 non-null  float64
#  8   위반신고전화번호   47874 non-null  object
#  9   소재지도로명주소   46312 non-null  object
#  10  소재지지번주소    14435 non-null  object
#  11  관리기관명      47874 non-null  object
#  12  위도         47410 non-null  float64
#  13  경도         47400 non-null  float64
#  14  데이터기준일자    47874 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 5.5+ MB

# %%
df_seoul_nonsmoking_sum = pd.read_csv(os.path.join(base_path, 'seoul_nonsmoking_sum.csv'))
se_a = df_seoul_nonsmoking_sum.iloc[1][1:]
df_1 = df_seoul_nonsmoking_sum.iloc[[2,4,6], :]
df_1 = df_1.transpose()
df_1.rename(columns={2 : '합계', 4 : '실내', 6 : '실외'}, inplace=True)
df_1 = df_1[1:]
df_1 = df_1.set_index(se_a)
df_1['실내'].fillna(0, inplace=True)
df_1.index.name = '서울시'
df_1
# Out:
#             합계       실내      실외
# 서울시
# 전체     287,200  269,794  17,406
# 건강증진과    2,155        0   2,155
# 종로구     10,873   10,634     239
# 중구      12,637   12,416     221
# 용산구      7,955    7,602     353
# 성동구      8,313    7,716     597
# 광진구      9,404    9,010     394
# 동대문구     9,830    9,368     462
# 중랑구      7,707    7,202     505
# 성북구     10,422    9,596     826
# 강북구      7,588    6,825     763
# 도봉구      6,392    5,916     476
# 노원구     10,331    9,505     826
# 은평구      9,466    9,021     445
# 서대문구     8,498    8,187     311
# 마포구     15,447   14,705     742
# 양천구      9,683    9,130     553
# 강서구     14,348   13,469     879
# 구로구     10,277    9,544     733
# 금천구      6,943    6,661     282
# 영등포구    13,822   12,974     848
# 동작구      8,331    7,677     654
# 관악구     10,516   10,056     460
# 서초구     16,498   15,402   1,096
# 강남구     30,304   29,426     878
# 송파구     17,749   16,597   1,152
# 강동구     11,711   11,155     556

# %%
df_seoul_nonsmoking_inplace = pd.read_csv(os.path.join(base_path, 'seoul_nonsmoking_inplace.csv'))
df_seoul_nonsmoking_inplace = df_seoul_nonsmoking_inplace[10:]
se_b =  df_seoul_nonsmoking_inplace.iloc[0]
se_b
# Out:
# Unnamed: 0       NaN
# Unnamed: 1        소계
# Unnamed: 2     건강증진과
# Unnamed: 3       종로구
# Unnamed: 4        중구
# Unnamed: 5       용산구
# Unnamed: 6       성동구
# Unnamed: 7       광진구
# Unnamed: 8      동대문구
# Unnamed: 9       중랑구
# Unnamed: 10      성북구
# Unnamed: 11      강북구
# Unnamed: 12      도봉구
# Unnamed: 13      노원구
# Unnamed: 14      은평구
# Unnamed: 15     서대문구
# Unnamed: 16      마포구
# Unnamed: 17      양천구
# Unnamed: 18      강서구
# Unnamed: 19      구로구
# Unnamed: 20      금천구
# Unnamed: 21     영등포구
# Unnamed: 22      동작구
# Unnamed: 23      관악구
# Unnamed: 24      서초구
# Unnamed: 25      강남구
# Unnamed: 26      송파구
# Unnamed: 27      강동구
# Name: 10, dtype: object

# %%
df_2 = df_seoul_nonsmoking_inplace[1:]
df_2 = df_2.transpose()
df_2 = df_2.set_index(se_b, inplace=True)
df_2

# %%
df_2
